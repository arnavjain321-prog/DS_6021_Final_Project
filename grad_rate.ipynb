# %% [markdown]
# # Exploring grad rates

# %%
import pandas as pd
import numpy as np

# %%
diplomas=pd.read_csv('Diplomas-and-Completion.csv',skiprows=3,skipfooter=1)
diplomas
# Out:
# /var/folders/p9/9vqlyg213v3b9h9zrksgz6z00000gn/T/ipykernel_12384/2260140521.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   diplomas=pd.read_csv('Diplomas-and-Completion.csv',skiprows=3,skipfooter=1)
#               Student Subgroup Advanced Diplomas Standard Diplomas  \
# 0                 All Students             50354             39349
# 1                       Female             27408             17323
# 2                         Male             22886             21945
# 3              American Indian               108               117
# 4                        Asian              6025              1443
# 5                        Black              8111             10540
# 6                     Hispanic              7130              8367
# 7              Native Hawaiian                97                61
# ...

# %%
diplomas['Student Subgroup'].value_counts()
# Out:
# Student Subgroup
# All Students                                                                                                                                                                             1
# Female                                                                                                                                                                                   1
# Foster Care                                                                                                                                                                              1
# Military Connected                                                                                                                                                                       1
# Homeless                                                                                                                                                                                 1
# ...

# %%
diplomas.dtypes
# Out:
# Student Subgroup       object
# Advanced Diplomas      object
# Standard Diplomas      object
# Other Diplomas         object
# GED's                  object
# Dropouts                int64
# Other Non-Graduates    object
# dtype: object

# %%
diplomas.index
# Out:
# RangeIndex(start=0, stop=17, step=1)

# %%
diplomas.loc[13].replace('<',np.nan,inplace=True)
diplomas
# Out:
# /var/folders/p9/9vqlyg213v3b9h9zrksgz6z00000gn/T/ipykernel_12384/1225848089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diplomas.loc[13].replace('<',np.nan,inplace=True)
#               Student Subgroup Advanced Diplomas Standard Diplomas  \
# 0                 All Students             50354             39349
# 1                       Female             27408             17323
# 2                         Male             22886             21945
# 3              American Indian               108               117
# 4                        Asian              6025              1443
# 5                        Black              8111             10540
# 6                     Hispanic              7130              8367
# 7              Native Hawaiian                97                61
# ...
