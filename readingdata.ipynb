# %%
import pandas as pd
import numpy as np
import plotly.express as px
df=pd.read_csv('final_dc.csv')
df.head()
# Out:
#      id                                           name  host_id host_name  \
# 0  3344  White House-Center City, entire 2BR/2BA Condo     4957      A.J.
# 1  3686                                Vita's Hideaway     4645      Vita
# 2  3943               Historic Rowhouse Near Monuments     5059      Vasa
# 3  4197             Capitol Hill Bedroom walk to Metro     5061    Sandra
# 4  4529                      Bertina's  House Part One     5803   Bertina
#
#          host_location                                      neighbourhood  \
# 0       Washington, DC  Downtown, Chinatown, Penn Quarters, Mount Vern...
# 1  Washington D.C., DC                                 Historic Anacostia
# 2       Washington, DC  Edgewood, Bloomingdale, Truxton Circle, Eckington
# 3  Washington D.C., DC                         Capitol Hill, Lincoln Park
# 4       Washington, DC                       Eastland Gardens, Kenilworth
#
#    latitude  longitude        room_type  accommodates  ...  min_nights  \
# ...

# %%
df['host_location'].value_counts()
# Out:
# host_location
# Washington, DC                 4063
# New York, NY                    402
# United States                    81
# Dubai, United Arab Emirates      67
# Hawthorne, NJ                    45
#                                ...
# Denver, CO                        1
# Ocean City, MD                    1
# Ashton-Sandy Spring, MD           1
# Arlington, TX                     1
# Bogotá, Colombia                  1
# Name: count, Length: 136, dtype: int64

# %%
df['host_location']=df['host_location'].replace('Washington, D.C., DC','Washington, DC')

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'host_location', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'accommodates', 'bathrooms',
#        'bedrooms', 'beds', 'amenities', 'price', 'min_nights', 'max_nights',
#        'estimated_occupancy_l365d', 'estimated_revenue_l365d', 'last_review',
#        'reviews_per_month', 'number_of_reviews', 'total_listings',
#        'availability_365', 'number_of_reviews_ltm'],
#       dtype='object')

# %% [markdown]
# ## Looking at Price

# %%
px.scatter(df,x='price')

# %% [markdown]
# We should so something with these data points that are far from 40k.

# %%
df_above_40k = df[df['price'] > 40000]
df_above_40k.head()
df_above_40k['price']
# Out:
# 3860    50000
# 3861    50000
# 3865    50000
# 3871    50000
# 3872    50000
# 3873    50000
# 3875    50000
# Name: price, dtype: int64

# %%
df_below_40k = df[df['price'] < 40000]
df_below_40k.head()
# Out:
#      id                                           name  host_id host_name  \
# 0  3344  White House-Center City, entire 2BR/2BA Condo     4957      A.J.
# 1  3686                                Vita's Hideaway     4645      Vita
# 2  3943               Historic Rowhouse Near Monuments     5059      Vasa
# 3  4197             Capitol Hill Bedroom walk to Metro     5061    Sandra
# 4  4529                      Bertina's  House Part One     5803   Bertina
#
#          host_location                                      neighbourhood  \
# 0       Washington, DC  Downtown, Chinatown, Penn Quarters, Mount Vern...
# 1  Washington D.C., DC                                 Historic Anacostia
# 2       Washington, DC  Edgewood, Bloomingdale, Truxton Circle, Eckington
# 3  Washington D.C., DC                         Capitol Hill, Lincoln Park
# 4       Washington, DC                       Eastland Gardens, Kenilworth
#
#    latitude  longitude        room_type  accommodates  ...  min_nights  \
# ...

# %% [markdown]
# ## Bedrooms Exploration

# %%
avg_price_by_bedroom=df.groupby('bedrooms')['price'].mean().reset_index()
avg_price_by_bedroom
# Out:
#     bedrooms       price
# 0          0   76.600372
# 1          1  275.804670
# 2          2  274.311820
# 3          3  446.406091
# 4          4  815.779026
# 5          5  208.414894
# 6          6  266.576923
# 7          7  382.666667
# 8          8  136.000000
# 9          9  609.000000
# 10        11    0.000000
# 11        12    0.000000

# %%
px.bar(avg_price_by_bedroom,x='bedrooms',y='price')

# %%
df['bedrooms'].value_counts()
# Out:
# bedrooms
# 1     3512
# 2     1379
# 3      591
# 0      538
# 4      267
# 5       94
# 6       26
# 7        9
# 8        4
# 12       1
# 11       1
# 9        1
# Name: count, dtype: int64

# %% [markdown]
# ## Name Exploration

# %%
df['name'].value_counts()
# Out:
# name
# Upscale and Great Location                           27
# 2 BR Fully Furnished Apartment at Penn Quarters -     6
# Sojourn on 17th | Pets Welcome                        6
# Blueground | Logan Circle, gym & w/d, nr metro        5
# Sojourn on 15th                                       5
#                                                      ..
# Sojourn the 13th Street Flats.                        1
# Modern Guest Suite in Chevy Chase, D.C                1
# Paradise in Petworth! Apt. Near Metro w/ Parking      1
# Nice beautiful room by Georgia metro station          1
# Lovely Luscious Cozy & Spacious Bedroom               1
# Name: count, Length: 6208, dtype: int64

# %%
df['name'].describe()
# Out:
# count                           6423
# unique                          6208
# top       Upscale and Great Location
# freq                              27
# Name: name, dtype: object

# %%
print(df['host_name'].value_counts())
print(df['host_name'].describe())
# Out:
# host_name
# Sojourn                 257
# Blueground              199
# Tina                    131
# Home Sweet City          85
# Global Luxury Suites     80
#                        ...
# Oritsetsemaye             1
# Doreen                    1
# Shajena And Gabriel       1
# Jtb                       1
# Yessenia                  1
# Name: count, Length: 1879, dtype: int64
# count        6420
# unique       1879
# top       Sojourn
# freq          257
# Name: host_name, dtype: object

# %%
df['neighbourhood'].value_counts()
df['neighbourhood'].describe()
# Out:
# count                                          6423
# unique                                           39
# top       Union Station, Stanton Park, Kingman Park
# freq                                            704
# Name: neighbourhood, dtype: object

# %% [markdown]
# ## Room Type

# %%
print(df['room_type'].value_counts())
print(df['room_type'].describe())
# Out:
# room_type
# Entire home/apt    4951
# Private room       1349
# Hotel room           94
# Shared room          29
# Name: count, dtype: int64
# count                6423
# unique                  4
# top       Entire home/apt
# freq                 4951
# Name: room_type, dtype: object
